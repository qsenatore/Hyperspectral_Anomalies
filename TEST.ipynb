# %% [markdown]
# Test du format jupyter pour la librairie spectrale

# %%
#Tests librairie SPy

#Libraires nécessaires pour utiliser SPy

#classique, on a l'habitude
import numpy as np

#traitement d'images
from PIL import Image

#création d'interfaces grpahiques
# import wx as wx  (version trop récente de python pour cette bibliothèque -> essayer sur version 3.10)

#pour faire des graphiques
import matplotlib as plt

#environnement interactif nécessaire pour des interfaces graphiques fluides
import IPython as ip


#finalement, la libraire spectral
from spectral import *

#ouvrir une image en python
img = open_image('92AV3C.lan')

print(img)

print()

#donne le type d'image (BIL,BIP,BSQ)
print("Type d'image : ")
print(img.__class__)
print()

#donne la forme de l'image (Lignes,Colonnes,Bandes)
print("Forme de l'image : ")
print(img.shape)
print()

#selectionner un pixel
pixel=img[50,100]

#selectionner une bande spectrale
band=img[:,:,5]

#charger l'image entière en mémoire cache (optimiser la performance algorithmique)
#arr = img.load()

#pour afficher l'image. Il faut lancer ipython dans le terminal avec la commande ipython --pylab
imshow(img,(29,19,9))
# Out:
# 	Data Source:   '././92AV3C.lan'
# 	# Rows:            145
# 	# Samples:         145
# 	# Bands:           220
# 	Interleave:        BIL
# 	Quantization:  16 bits
# 	Data format:     int16
#
# Type d'image :
# <class 'spectral.io.bilfile.BilFile'>
#
# Forme de l'image :
# (145, 145, 220)
# /home/j_lauren/.local/lib/python3.12/site-packages/spectral/graphics/spypylab.py:796: UserWarning: Failed to create RectangleSelector object. Interactive pixel class labeling will be unavailable.
#   warnings.warn(msg)
# ImageView object:
#   Display bands       :  (1, 2, 3)
#   Interpolation       :  <default>
#   RGB data limits     :
#     R: [3477.0, 5744.0]
#     G: [3649.0, 6361.0]
#     B: [3578.0, 6362.0]
